# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
original_data = pd.read_excel('../filna/dr.atashi.tasbihchi.xlsx')
original_data.head(10)
original_data.info()
original_data.tail()
original_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5876 entries, 0 to 5875
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5876 non-null   int64
#  1   age                4879 non-null   float64
#  2   age.diag           5781 non-null   float64
#  3   age.menarch        5425 non-null   float64
#  4   age.menop          4910 non-null   float64
#  5   Occupation         300 non-null    float64
#  6   education          5025 non-null   float64
#  7   marital            5591 non-null   float64
#  8   gravity            5379 non-null   float64
#  9   lactaton           5230 non-null   float64
#  10  first.pregnancy    5205 non-null   float64
#  11  infertility        3988 non-null   float64
#  12  reproduct          5189 non-null   float64
#  13  mens               3918 non-null   float64
#  14  ocp.use            4184 non-null   float64
# ...

# %%
FIX_data = pd.read_csv('../classfier/output.csv')
FIX_data.head(10)
FIX_data.info()
FIX_data.tail()
FIX_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5876 entries, 0 to 5875
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5876 non-null   int64
#  1   age                5876 non-null   float64
#  2   age.diag           5876 non-null   float64
#  3   age.menarch        5876 non-null   float64
#  4   age.menop          5876 non-null   float64
#  5   Occupation         5876 non-null   float64
#  6   education          5876 non-null   float64
#  7   marital            5876 non-null   float64
#  8   gravity            5876 non-null   float64
#  9   lactaton           5876 non-null   float64
#  10  first.pregnancy    5876 non-null   float64
#  11  infertility        5876 non-null   float64
#  12  reproduct          5876 non-null   float64
#  13  mens               5876 non-null   float64
#  14  ocp.use            5876 non-null   float64
# ...

# %%
fig , ax = plt.subplots()
ax.scatter(FIX_data['age'],FIX_data['weight'])
ax.set_xlabel('weight')
ax.set_ylabel('age')
plt.show()
plt.close('all')

# %%
fig , ax = plt.subplots()
ax.scatter(original_data['age'],original_data['weight'])
ax.set_xlabel('weight')
ax.set_ylabel('age')
plt.show()
plt.close('all')
